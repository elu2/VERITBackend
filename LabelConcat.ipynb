# %%
import pandas as pd

# %% [markdown]
# This program takes a dataframe and labels the Activation(Positive) as 1 and Activation(Negative) as -1. It then cbinds it to the dataframe to create xxx_labelled.csv.

# %% [markdown]
# For the basic Activation-type event labels.

# %%
# For activations:
file = "pos_neg_counted_df.csv"
df = pd.read_csv(file)
df
# Out:
#         Unnamed: 0                                              INPUT  \
# 0                1                           oxytocin::uniprot:P01178
# 1                2                           apoptosis::go:GO:0006915
# 2                3                        inflammation::go:GO:0006954
# 3                4                   insulin secretion::go:GO:0030073
# 4                5                              FBS::uniprot:Q9HAH7.a
# ...            ...                                                ...
# 132694      132695                                ‐8::uaz:UAZE2809038
# 132695      132696  ′-CTGCTGGATGACGTGAGGT AACC-3′::uaz:UAZE280B22D...
# 132696      132697                                ’s::uaz:UAZE2809973
# 132697      132698                                   ♂::uaz:UAZE29982
# 132698      132699                                   ﬁ::uaz:UAZEFAC81
#
#                                                    OUTPUT  \
# 0                                                     NaN
# 1                              apoptosis::go:GO:0006915.a
# 2                           inflammation::go:GO:0006954.a
# 3                      insulin secretion::go:GO:0030073.a
# 4                                     FBS::uniprot:Q9HAH7
# ...                                                   ...
# 132694                              ‐8::uaz:UAZE2809038.a
# 132695  ′-CTGCTGGATGACGTGAGGT AACC-3′::uaz:UAZE280B22D...
# 132696                              ’s::uaz:UAZE2809973.a
# 132697                                 ♂::uaz:UAZE29982.a
# 132698                                 ﬁ::uaz:UAZEFAC81.a
#
#                                                CONTROLLER  \
# 0                                                     NaN
# 1                                  ROS::chebi:CHEBI:26523
# 2                                     LPS::uniprot:O14896
# 3                              glucose::chebi:CHEBI:17234
# 4                                      heat::pfam:PF02985
# ...                                                   ...
# 132694                 mycoplasma infection::mesh:D009175
# 132695  probe (5′-VIC TGTCTCGCTCCGTGGCCTTAGCTG-3′::uaz...
# 132696                                   MVs::pubchem:449
# 132697                             cecropin::pfam:PF00272
# 132698                               betaine::pubchem:247
#
#                   EVENT_LABEL  COUNTER     SEEN_IN
# 0                         NaN      209         NaN
# 1       Activation (Positive)       57  PMC6947900
# 2       Activation (Positive)       45  PMC6997189
# 3       Activation (Positive)       43  PMC6997356
# 4       Activation (Negative)       36  PMC6951253
# ...                       ...      ...         ...
# 132694  Activation (Positive)        1  PMC7027758
# 132695  Activation (Negative)        1  PMC7005185
# 132696  Activation (Positive)        1  PMC7072151
# 132697  Activation (Positive)        1  PMC7032688
# 132698  Activation (Positive)        1  PMC7587910
#
# [132699 rows x 7 columns]

# %%
numeric_labels = {"NUM_LABEL": []}
for label in df.EVENT_LABEL:
    if label == "Activation (Negative)":
        numeric_labels["NUM_LABEL"].append(-1)
    elif label == "Activation (Positive)":
        numeric_labels["NUM_LABEL"].append(1)
    else:
        numeric_labels["NUM_LABEL"].append(0)

# %%
df = pd.concat([df, pd.DataFrame(numeric_labels)], axis=1)
df
# Out:
#         Unnamed: 0                                              INPUT  \
# 0                1                           oxytocin::uniprot:P01178
# 1                2                           apoptosis::go:GO:0006915
# 2                3                        inflammation::go:GO:0006954
# 3                4                   insulin secretion::go:GO:0030073
# 4                5                              FBS::uniprot:Q9HAH7.a
# ...            ...                                                ...
# 132694      132695                                ‐8::uaz:UAZE2809038
# 132695      132696  ′-CTGCTGGATGACGTGAGGT AACC-3′::uaz:UAZE280B22D...
# 132696      132697                                ’s::uaz:UAZE2809973
# 132697      132698                                   ♂::uaz:UAZE29982
# 132698      132699                                   ﬁ::uaz:UAZEFAC81
#
#                                                    OUTPUT  \
# 0                                                     NaN
# 1                              apoptosis::go:GO:0006915.a
# 2                           inflammation::go:GO:0006954.a
# 3                      insulin secretion::go:GO:0030073.a
# 4                                     FBS::uniprot:Q9HAH7
# ...                                                   ...
# 132694                              ‐8::uaz:UAZE2809038.a
# 132695  ′-CTGCTGGATGACGTGAGGT AACC-3′::uaz:UAZE280B22D...
# 132696                              ’s::uaz:UAZE2809973.a
# 132697                                 ♂::uaz:UAZE29982.a
# 132698                                 ﬁ::uaz:UAZEFAC81.a
#
#                                                CONTROLLER  \
# 0                                                     NaN
# 1                                  ROS::chebi:CHEBI:26523
# 2                                     LPS::uniprot:O14896
# 3                              glucose::chebi:CHEBI:17234
# 4                                      heat::pfam:PF02985
# ...                                                   ...
# 132694                 mycoplasma infection::mesh:D009175
# 132695  probe (5′-VIC TGTCTCGCTCCGTGGCCTTAGCTG-3′::uaz...
# 132696                                   MVs::pubchem:449
# 132697                             cecropin::pfam:PF00272
# 132698                               betaine::pubchem:247
#
#                   EVENT_LABEL  COUNTER     SEEN_IN  NUM_LABEL
# 0                         NaN      209         NaN          0
# 1       Activation (Positive)       57  PMC6947900          1
# 2       Activation (Positive)       45  PMC6997189          1
# 3       Activation (Positive)       43  PMC6997356          1
# 4       Activation (Negative)       36  PMC6951253         -1
# ...                       ...      ...         ...        ...
# 132694  Activation (Positive)        1  PMC7027758          1
# 132695  Activation (Negative)        1  PMC7005185         -1
# 132696  Activation (Positive)        1  PMC7072151          1
# 132697  Activation (Positive)        1  PMC7032688          1
# 132698  Activation (Positive)        1  PMC7587910          1
#
# [132699 rows x 8 columns]

# %%
df.to_csv("pos_neg_counted_labelled_df.csv")

# %% [markdown]
# For the NONE CONTROLLERS with more unique id labels.

# %%
# For NONE CONTROLLERS:
file = "none_counted_df.csv"
df = pd.read_csv(file)
df
# Out:
#      INPUT                     OUTPUT                 CONTROLLER  \
# 0       E3      Bax::uniprot:Q07812.t    Bcl-2::uniprot:P10415.t
# 1       E5    Bcl-2::uniprot:P10415.t      Bax::uniprot:Q07812.t
# 2       E7  Jagged1::uniprot:P78504.t      Bax::uniprot:Q07812.t
# 3      E48   Notch1::uniprot:P46531.t      Bax::uniprot:Q07812.t
# 4      E38     PCNA::uniprot:P12004.t      Bax::uniprot:Q07812.t
# ...    ...                        ...                        ...
# 3039    E3           η::uaz:UAZCEB7.t            Eq::uaz:UAZ4571
# 3040    E3           Δ::uaz:UAZCE94.a       Fpr2::uniprot:P25090
# 3041    E3           Δ::uaz:UAZCE94.a       Gls1::uniprot:O94925
# 3042    E3           Δ::uaz:UAZCE94.m      SMTs::uaz:UAZ534D5473
# 3043    E3           Δ::uaz:UAZCE94.m  sterol::chebi:CHEBI:15889
#
#                               EVENT_LABEL  COUNTER     SEEN_IN
# 0     Regulation (Negative) Transcription        5  PMC6967094
# 1     Regulation (Positive) Transcription        4  PMC6998203
# 2     Regulation (Negative) Transcription        4  PMC6967094
# 3     Regulation (Negative) Transcription        4  PMC6967094
# 4     Regulation (Negative) Transcription        4  PMC6967094
# ...                                   ...      ...         ...
# 3039  Regulation (Positive) Transcription        1  PMC7005004
# 3040         Regulation (Negative) Amount        1  PMC7001479
# 3041         Regulation (Negative) Amount        1  PMC7001479
# 3042    Regulation (Positive) Methylation        1  PMC6997595
# 3043    Regulation (Positive) Methylation        1  PMC6997595
#
# [3044 rows x 6 columns]

# %%
numeric_labels = {"NUM_LABEL": []}
for label in df.EVENT_LABEL:
    _, pos_neg, label_type = label.split(" ")
    
    if pos_neg == "(Negative)": 
        if label_type == "Amount":
            numeric_labels["NUM_LABEL"].append(1)
        elif label_type == "Transcription":
            numeric_labels["NUM_LABEL"].append(-1)
        elif label_type == "Ubiquitination":
            numeric_labels["NUM_LABEL"].append(1)
        else:
            numeric_labels["NUM_LABEL"].append(0)

    elif pos_neg == "(Positive)":
        if label_type == "Amount":
            numeric_labels["NUM_LABEL"].append(-1)
        elif label_type == "Transcription":
            numeric_labels["NUM_LABEL"].append(1)
        elif label_type == "Ubiquitination":
            numeric_labels["NUM_LABEL"].append(-1)
        else:
            numeric_labels["NUM_LABEL"].append(0)

# %%
df = pd.concat([df, pd.DataFrame(numeric_labels)], axis=1)
df
# Out:
#      INPUT                     OUTPUT                 CONTROLLER  \
# 0       E3      Bax::uniprot:Q07812.t    Bcl-2::uniprot:P10415.t
# 1       E5    Bcl-2::uniprot:P10415.t      Bax::uniprot:Q07812.t
# 2       E7  Jagged1::uniprot:P78504.t      Bax::uniprot:Q07812.t
# 3      E48   Notch1::uniprot:P46531.t      Bax::uniprot:Q07812.t
# 4      E38     PCNA::uniprot:P12004.t      Bax::uniprot:Q07812.t
# ...    ...                        ...                        ...
# 3039    E3           η::uaz:UAZCEB7.t            Eq::uaz:UAZ4571
# 3040    E3           Δ::uaz:UAZCE94.a       Fpr2::uniprot:P25090
# 3041    E3           Δ::uaz:UAZCE94.a       Gls1::uniprot:O94925
# 3042    E3           Δ::uaz:UAZCE94.m      SMTs::uaz:UAZ534D5473
# 3043    E3           Δ::uaz:UAZCE94.m  sterol::chebi:CHEBI:15889
#
#                               EVENT_LABEL  COUNTER     SEEN_IN  NUM_LABEL
# 0     Regulation (Negative) Transcription        5  PMC6967094         -1
# 1     Regulation (Positive) Transcription        4  PMC6998203          1
# 2     Regulation (Negative) Transcription        4  PMC6967094         -1
# 3     Regulation (Negative) Transcription        4  PMC6967094         -1
# 4     Regulation (Negative) Transcription        4  PMC6967094         -1
# ...                                   ...      ...         ...        ...
# 3039  Regulation (Positive) Transcription        1  PMC7005004          1
# 3040         Regulation (Negative) Amount        1  PMC7001479          1
# 3041         Regulation (Negative) Amount        1  PMC7001479          1
# 3042    Regulation (Positive) Methylation        1  PMC6997595          0
# 3043    Regulation (Positive) Methylation        1  PMC6997595          0
#
# [3044 rows x 7 columns]

# %%
df.to_csv("none_counted_labelled_df.csv")
